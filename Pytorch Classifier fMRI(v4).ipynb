# %% [markdown]
# # Functional connectiviy Template
# ### (Classifier)
# ![image.png](attachment:image.png)

# %%
# Import necessary libraries
import os
import json
import numpy as np
import pandas as pd
import seaborn as sns
from glob import glob
from pathlib import Path
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import matplotlib.patches as mpatches
from matplotlib import colormaps, colors
from nilearn import datasets, maskers, plotting
from nilearn.maskers import NiftiLabelsMasker
from nilearn.connectome import ConnectivityMeasure


# Ignore warnings for cleaner output
import warnings
warnings.filterwarnings('ignore')

# %%
pip install optuna-integration
# Out:
# Collecting optuna-integration
#   Downloading optuna_integration-4.0.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: optuna in /opt/conda/lib/python3.10/site-packages (from optuna-integration) (3.6.1)
# Requirement already satisfied: alembic>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from optuna->optuna-integration) (1.13.2)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.10/site-packages (from optuna->optuna-integration) (6.8.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from optuna->optuna-integration) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from optuna->optuna-integration) (21.3)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from optuna->optuna-integration) (2.0.30)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from optuna->optuna-integration) (4.66.4)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from optuna->optuna-integration) (6.0.2)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic>=1.5.0->optuna->optuna-integration) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.10/site-packages (from alembic>=1.5.0->optuna->optuna-integration) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->optuna->optuna-integration) (3.1.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna->optuna-integration) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/conda/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna->optuna-integration) (2.1.5)
# Downloading optuna_integration-4.0.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 1.2 MB/s eta 0:00:00a 0:00:010m
# Installing collected packages: optuna-integration
# Successfully installed optuna-integration-4.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Deep Learning libraries
import torch
import optuna
import torch.nn as nn
import torch.optim as optim
from sklearn import metrics
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import roc_auc_score, precision_recall_curve, auc
from optuna.integration import PyTorchLightningPruningCallback

# Device selection: DirectML or fallback to CUDA/CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Functions

def fetch_func_files(wdir, file_suffix='_bold.nii.gz'):
    # Construct the search pattern using the file suffix
    pattern = f'**/*{file_suffix}'
    
    # Convert wdir to a Path object if it's not already one
    wdir = Path(wdir)
    
    # Use glob to find and sort the files matching the pattern
    func_files = sorted(glob(str(wdir / pattern), recursive=True))
    
    # Print the number of files found
    print(f"Number of functional files with suffix '{file_suffix}': {len(func_files)}")
    
    # Return the list of functional file paths
    return func_files
# data = fetch_func_files(wdir, file_suffix='_bold.nii.gz' )

def fetch_dss_files(wdir, task_name='rest'):
    # Construct the search pattern based on the task name
    pattern = f'**/sub-*/func/*task-{task_name}_bold.nii.gz'

    
    # Convert wdir to a Path object if it's not already one
    wdir = Path(wdir)
    
    # Use glob to find and sort the files matching the pattern
    func_files = sorted(glob(str(wdir / pattern), recursive=True))
    
    # Print the number of files found
    print(f"Number of '{task_name}' functional files: {len(func_files)}")
    
    # Return the list of functional file paths
    return func_files
# data_func = fetch_dss_files(wdir, task_name='rest')

def load_json_file(file_name, data_dir):

    data_dir = Path(data_dir)
    file_path = data_dir / file_name
    
    # Check if the file exists
    if not file_path.exists():
        raise FileNotFoundError(f"The file {file_path} does not exist.")
    
    # Read the JSON file
    with file_path.open('r', encoding='utf-8') as file:
        data = json.load(file)
    
    # Print the contents of the JSON file
    print(json.dumps(data, indent=4))
    
    return data
# df_description = load_json_file("dataset_description.json", data_dir=wdir)

# %%
# Shortcuts

#dataset = datasets.fetch_adhd(n_subjects=None, data_dir=None, url=None, resume=True, verbose=1)

#dataset = datasets.fetch_openneuro_dataset(urls=None, data_dir=None, dataset_version='ds000030_R1.0.5', verbose=1)[source]

#dataset = datasets.fetch_abide_pcp(n_subjects=None, data_dir=None, url=None)

#dataset = datasets.fetch_development_fmri()

#pheno = pd.DataFrame(dataset.phenotypic)

#print('Keys:',list(data.keys()))
#print('Number of subjects:', len(data.func))
#print('Description:',data.description)


#---------------------------------------------


#wdir = r'C:\Users\lacom\nilearn_data\development_fmri\development_fmri'

#data_func = sorted(glob(os.path.join(wdir,'*.gz')))
#confounds = sorted(glob(os.path.join(wdir,'*desc-confounds_regressors.tsv')))

#print ('Func Data:',len(data))
#print ('Confounds:',len(confounds))

#pheno_path = os.path.join(wdir, 'participants.tsv')
#pheno = pd.read_csv(pheno_path, sep='\t').sort_values('participant_id')
#pheno.head()

# %% [markdown]
# ## Load the data

# %%
dataset = datasets.fetch_development_fmri()

print('Keys:',list(dataset.keys()))
print('Number of subjects:', len(dataset.func))
# Out:
# Added README.md to /root/nilearn_data
#
#
# Dataset created in /root/nilearn_data/development_fmri
#
#
# Added README.md to /root/nilearn_data/development_fmri
#
#
# Dataset created in /root/nilearn_data/development_fmri/development_fmri
#
# Downloading data from https://osf.io/yr3av/download ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3df4712b400183b7092/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3e04712b400193b5bdf/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3e14712b400183b7097/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3e32286e80018c3e42c/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3e4a743a9001760814f/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3e54712b400183b70a5/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3e52286e80018c3e439/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3e72286e80017c41b3d/ ...
#  ...done. (5 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3e9a743a90017608158/ ...
#  ...done. (7 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3e82286e80018c3e443/ ...
#  ...done. (8 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3ea4712b400183b70b7/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3eb2286e80019c3c194/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3eb2286e80019c3c198/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3ed2286e80017c41b56/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3ee2286e80016c3c379/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3ee4712b400183b70c3/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3efa743a9001660a0d5/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3f14712b4001a3b560e/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3f1a743a90017608164/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3f12286e80016c3c37e/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3f34712b4001a3b5612/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3f7a743a90019606cdf/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3f6a743a90017608171/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3f64712b400183b70d8/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3f72286e80019c3c1af/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3f92286e80018c3e463/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4534712b400183b716d/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3fb2286e80017c41b72/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3fb2286e80019c3c1b3/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3fd4712b400183b70e6/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3fe4712b4001a3b5620/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3ff4712b400173b5399/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff401a743a9001660a104/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff403a743a90017608181/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4034712b400183b70f6/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4042286e80019c3c1c2/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4052286e80017c41b92/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4064712b400183b70fe/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4074712b400183b7104/ ...
#  ...done. (6 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff40aa743a9001660a119/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4092286e80017c41ba7/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff40b2286e80016c3c39a/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff40d2286e80016c3c39f/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff40da743a90018606eac/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff40e4712b400173b53a8/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4104712b400173b53ad/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4112286e80016c3c3a5/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff412a743a9001660a128/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff414a743a90019606cfc/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff416a743a90019606d01/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff417a743a9001660a130/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4184712b400193b5c19/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff41a2286e80019c3c1de/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff41aa743a9001660a13b/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff41b2286e80016c3c3b6/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff41d2286e80018c3e499/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff41da743a900176081a2/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff41ea743a90018606ec7/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4202286e80019c3c1e2/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4212286e80018c3e49d/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4212286e80019c3c1e6/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff424a743a900176081af/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4264712b400193b5c2f/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4252286e80017c41bfc/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4282286e80017c41c0a/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff4292286e80017c41c0f/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff37da743a90018606df1/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff37c2286e80019c3c102/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4701e3992690018133d4f/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e6b353c58001b9cb34f/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff37d4712b400193b5b54/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff37d4712b400183b7011/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff37e2286e80016c3c2cb/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3832286e80019c3c10f/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3822286e80018c3e37b/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff382a743a90018606df8/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3814712b4001a3b5561/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3832286e80016c3c2d1/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3842286e80017c419e0/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3854712b4001a3b5568/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4702f39926900171090ee/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e8b353c58001c9abe98/ ...
#  ...done. (6 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3872286e80017c419ea/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3872286e80017c419e9/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3884712b400183b7023/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3884712b400193b5b5c/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff389a743a9001660a016/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff38c2286e80016c3c2da/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff38ca743a90018606dfe/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff38ca743a9001760809e/ ...
#  ...done. (7 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47056353c58001c9ac064/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e5af2be3c001801f799/ ...
#  ...done. (5 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4703bf2be3c001801fa49/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e92a3bc970019f0717f/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff38c4712b4001a3b5573/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff38da743a900176080a2/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47016a3bc970017efe44f/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e43f2be3c0017056b8a/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb470413992690018133d8c/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e9a353c58001c9abeac/ ...
#  ...done. (5 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff38f2286e80018c3e38d/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3914712b4001a3b5579/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4702a353c58001b9cb5ae/ ...
#  ...done. (11 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e9b39926900190fad5c/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff391a743a900176080a9/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3914712b400173b5329/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47023353c58001c9ac02b/ ...
#  ...done. (5 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46eaa39926900160f69af/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3912286e80018c3e393/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3952286e80017c41a1b/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47045a3bc970019f073a0/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e913992690018133b1c/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47052f2be3c0017057069/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e5c353c5800199ac79f/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47057f2be3c0019030a1f/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e63f2be3c0017056ba9/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4704af2be3c001705703b/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e7a353c58001a9b3324/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3952286e80016c3c2e7/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3954712b400193b5b79/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47016a3bc970018f1fc88/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e6ba3bc970019f07152/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff395a743a900176080af/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3964712b400193b5b7d/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff399a743a9001660a031/ ...
#  ...done. (5 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3982286e80017c41a29/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff39aa743a90018606e21/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff39aa743a900176080ba/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb470153992690018133d3b/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e793992690017108eb9/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47038353c5800199ac9a2/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e85a3bc97001aeff750/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4701c3992690018133d49/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e1c3992690018133a9e/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff39aa743a900176080bf/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff39d4712b400193b5b89/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4703039926900160f6b3e/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e4d353c58001b9cb325/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4700af2be3c0017056f69/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e0cf2be3c001801f757/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4702b39926900171090e4/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e35f2be3c00190305ff/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff39ca743a90019606c50/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3a2a743a9001660a048/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4701ff2be3c0017056fad/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e0339926900160f6930/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3a12286e80017c41a48/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3a12286e80016c3c2fc/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff39fa743a90018606e2f/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3a34712b4001a3b55a3/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4703439926900160f6b43/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e40f2be3c001801f77f/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3a34712b400193b5b92/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3a84712b400183b7048/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47020f2be3c0019030968/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e6f353c58001a9b3311/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3a72286e80017c41a54/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3a7a743a90018606e42/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4702639926900190faf1d/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e3f353c5800199ac787/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47049353c5800199ac9b4/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46eaa353c58001c9abebb/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3a74712b4001a3b55ad/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3a72286e80017c41a59/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3aa4712b400183b704d/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3ac4712b4001a3b55b7/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47051f2be3c001601df24/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e12f2be3c001801f75e/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3aca743a9001660a063/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3ac4712b400183b7051/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47032a3bc970019f07386/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e42353c58001b9cb311/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47036f2be3c001801fa3d/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e6539926900190fad0c/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47057353c58001a9b353f/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46ea4353c58001b9cb3a6/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4703af2be3c001601def7/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e51f2be3c001801f78e/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3ae4712b400183b7055/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3af2286e80018c3e3c0/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3b02286e80018c3e3c4/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3b14712b400183b705a/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47029f2be3c0019030994/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e17f2be3c00190305da/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47047f2be3c0017057034/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e23a3bc970018f1fa00/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3b12286e80016c3c30f/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3b34712b400183b7060/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3b2a743a9001660a07a/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3b54712b400193b5ba3/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c9e99d006cd47001a5ab599/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3b62286e80016c3c31b/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47011f2be3c001903092f/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e54353c58001a9b32f3/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3b72286e80017c41a88/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3b94712b4001a3b55bf/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47039a3bc970018f1fcbf/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e983992690017108ed8/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3b92286e80017c41a8e/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3b92286e80018c3e3e0/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3ba2286e80016c3c325/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3bd2286e80017c41a9e/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4700bf2be3c001801f9c3/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e22f2be3c0017056b52/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47019a3bc970017efe457/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e1fa3bc970018f1f9f5/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb470313992690018133d6d/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e85f2be3c001601dc65/ ...
#  ...done. (5 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3be4712b400193b5bab/ ...
#  ...done. (5 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3bf2286e80017c41aa8/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3be4712b4001a3b55c4/ ...
#  ...done. (7 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3c12286e80017c41ab1/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3c34712b400173b5362/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3c42286e80017c41ab6/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47010f2be3c0017056f80/ ...
#  ...done. (5 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46ea03992690017108ee8/ ...
#  ...done. (6 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47022f2be3c0017056fb9/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e30353c58001b9cb2f5/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3c44712b400183b7071/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3c42286e80017c41abc/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4700cf2be3c0017056f70/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e4fa3bc970019f0713b/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4702af2be3c001601debb/ ...
#  ...done. (6 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e75353c58001a9b331b/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3c7a743a90018606e5f/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3c9a743a90017608120/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47019f2be3c0019030945/ ...
#  ...done. (5 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e5ba3bc97001aeff72b/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4702cf2be3c0017056fdb/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e4b353c5800199ac78f/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4701a39926900171090bb/ ...
#  ...done. (6 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46ea7353c58001b9cb3ac/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47010a3bc970019f0735c/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e8e3992690017108ed0/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb470423992690018133d92/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e46a3bc970018f1fa36/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4700df2be3c001801f9c8/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e4f353c58001a9b32e9/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4702ff2be3c00190309b0/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e8af2be3c0017056be0/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47047f2be3c001801fa64/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46ea43992690017108ef5/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3c94712b4001a3b55d3/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3c9a743a9001760811a/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3ca4712b400183b707a/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3cc2286e80017c41adc/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47027f2be3c0017056fd0/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e38a3bc970018f1fa25/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47028f2be3c001801fa13/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e2fa3bc970018f1fa11/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47050f2be3c0017057062/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e77f2be3c001601dc4f/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4701e39926900171090c7/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e82f2be3c001903063e/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47015f2be3c001801f9df/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e8139926900160f698a/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47013f2be3c0019030935/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e65353c58001b9cb346/ ...
#  ...done. (5 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3cea743a90019606c9f/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3cea743a90018606e68/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47025f2be3c001801fa04/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e09a3bc970018f1f9d8/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47044a3bc970018f1fccc/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e29f2be3c0017056b6a/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47042f2be3c0017057025/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e64a3bc970019f0714b/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4705239926900160f6b74/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e00f2be3c001601dbf3/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4704d353c58001b9cb5d8/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46dfff2be3c001601dbef/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3ce2286e80016c3c34b/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3d12286e80019c3c16f/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47010f2be3c0019030921/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e0539926900160f6935/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47052353c58001b9cb5e3/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46df9f2be3c0017056b01/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4700d353c58001b9cb57d/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46dfef2be3c0017056b15/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb470383992690018133d76/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46dfc3992690018133a72/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4703ef2be3c00190309d3/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e0ea3bc970019f0710c/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3d3a743a90019606caa/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3d34712b400193b5bc7/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3d22286e80017c41af2/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3d52286e80017c41afe/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4704ef2be3c001801fa79/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e7339926900190fad1a/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4700fa3bc97001aeff8f0/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e16f2be3c0017056b3e/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3d84712b400183b708c/ ...
#  ...done. (4 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3d7a743a90017608138/ ...
#  ...done. (5 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4704cf2be3c0017057049/ ...
#  ...done. (6 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e34a3bc97001aeff717/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb470553992690018133dbe/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e29f2be3c001601dc17/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3d8a743a90019606cb5/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3d8a743a90018606e75/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3dba743a90018606e7e/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3de4712b4001a3b55f4/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47017f2be3c0017056f8d/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e13f2be3c0017056b37/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4704ca3bc970018f1fcda/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e0b39926900160f693c/ ...
#  ...done. (3 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb4704c3992690018133da6/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e1c3992690018133aa2/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3dc4712b4001a3b55f0/ ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://osf.io/download/5c8ff3df2286e80018c3e421/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb47021353c58001b9cb59f/ ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://osf.io/download/5cb46e2f353c58001b9cb2f1/ ...
#  ...done. (2 seconds, 0 min)
# Keys: ['func', 'confounds', 'phenotypic', 'description']
# Number of subjects: 155

# %%
'''import shutil

# Define the source and destination paths
source_folder = '/root/nilearn_data/development_fmri'
destination_folder = '/kaggle/working/development_fmri'

# Copy the entire folder to the working directory
shutil.copytree(source_folder, destination_folder)

# Verify the copied folder
import os
print("Files in /kaggle/working/development_fmri/:")
print(os.listdir(destination_folder))
'''
# Out:
# 'import shutil\n\n# Define the source and destination paths\nsource_folder = \'/root/nilearn_data/development_fmri\'\ndestination_folder = \'/kaggle/working/development_fmri\'\n\n# Copy the entire folder to the working directory\nshutil.copytree(source_folder, destination_folder)\n\n# Verify the copied folder\nimport os\nprint("Files in /kaggle/working/development_fmri/:")\nprint(os.listdir(destination_folder))\n'

# %%
import os

# Check the size of the folder
def get_size(path):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(path):
        for filename in filenames:
            filepath = os.path.join(dirpath, filename)
            total_size += os.path.getsize(filepath)
    return total_size

folder_size = get_size('/kaggle/working/development_fmri')
print(f"Folder size: {folder_size / (1024 ** 3):.2f} GiB")
# Out:
# Folder size: 0.00 GiB

# %%
'''import shutil

# Path to the folder and the ZIP file
folder_to_zip = '/kaggle/working/development_fmri'
zip_file_path = '/kaggle/working/development_fmri.zip'

# Create a ZIP file from the folder
shutil.make_archive('/kaggle/working/development_fmri', 'zip', folder_to_zip)

# Verify the ZIP file
import os
print("Files in /kaggle/working/:")
print(os.listdir('/kaggle/working'))'''
# Out:
# 'import shutil\n\n# Path to the folder and the ZIP file\nfolder_to_zip = \'/kaggle/working/development_fmri\'\nzip_file_path = \'/kaggle/working/development_fmri.zip\'\n\n# Create a ZIP file from the folder\nshutil.make_archive(\'/kaggle/working/development_fmri\', \'zip\', folder_to_zip)\n\n# Verify the ZIP file\nimport os\nprint("Files in /kaggle/working/:")\nprint(os.listdir(\'/kaggle/working\'))'

# %%
data = dataset.func

# %%
print('Description:',dataset.description)
# Out:
# Description: .. _development_dataset:
#
# development fMRI dataset
# ========================
#
# Access
# ------
# See :func:`nilearn.datasets.fetch_development_fmri`.
#
# Notes
# -----
# This movie-watching based functional MRI dataset is used for teaching how to use
# machine learning to predict age from naturalistic stimuli (movie)
# watching with Nilearn.
#
# The dataset consists of 50 children (ages 3-13) and 33 young adults (ages
# 18-39). This dataset can be used to try to predict who are adults and
# who are children.
#
# The data is downsampled to 4mm resolution for convenience. The original
# data is downloaded from OpenNeuro.
#
# For full information about pre-processing steps on raw-fMRI data, have a look
# at README at https://osf.io/wjtyq/
#
# Full pre-processed data: https://osf.io/5hju4/files/
#
# Raw data can be accessed from : https://openneuro.org/datasets/ds000228/versions/1.0.0
#
# See :footcite:t:`Richardson2018`.
#
# Content
# -------
#     :'func': functional MRI Nifti images (4D) per subject
#     :'confounds': TSV file contain nuisance information per subject
#     :'phenotypic': Phenotypic information for each subject such as age,
#                    age group, gender, handedness.
#
# References
# ----------
#
# .. footbibliography::
#
# License
# -------
# usage is unrestricted for non-commercial research purposes.

# %%
fmri_filenames = data[5]
print(fmri_filenames)
# Out:
# /root/nilearn_data/development_fmri/development_fmri/sub-pixar128_task-pixar_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz

# %%
from nilearn import image 
averaged_Img = image.mean_img(image.mean_img(fmri_filenames))
plotting.plot_stat_map(averaged_Img,title='Average Image', cmap='viridis',threshold=0.1, dim=-2, colorbar=True,black_bg=True)

# %%
confounds = dataset.confounds
conf = confounds[5]
conf_df = pd.read_table(conf)
conf_df.head()
# Out:
#     trans_x   trans_y   trans_z     rot_x     rot_y  rot_z  \
# 0  0.000000  0.000000  0.000000  0.000000 -0.000000    0.0
# 1  0.002290  0.039488 -0.000004  0.000000  0.000190    0.0
# 2 -0.000011 -0.104030 -0.009560  0.000164  0.000366    0.0
# 3 -0.000031  0.169104  0.013041 -0.000843  0.000453    0.0
# 4 -0.000061 -0.145348 -0.025025  0.000060  0.000386    0.0
#
#    framewise_displacement  a_comp_cor_00  a_comp_cor_01  a_comp_cor_02  \
# 0                0.000000       0.000000       0.000000       0.000000
# 1                0.051301      -0.009419       0.064324      -0.046474
# 2                0.172322      -0.013124       0.010970       0.072557
# 3                0.350465       0.033150       0.025784       0.036211
# 4                0.401084      -0.035600      -0.035397      -0.127860
#
#    a_comp_cor_03  a_comp_cor_04  a_comp_cor_05         csf  white_matter
# 0       0.000000       0.000000       0.000000  525.521464    473.476960
# 1       0.006744      -0.007179       0.025285  529.577966    476.734232
# 2       0.030795       0.015773      -0.063280  531.250261    476.517911
# 3       0.005530       0.048968      -0.025824  531.240585    476.460569
# 4       0.001092      -0.031902       0.048258  531.931781    476.174483

# %% [markdown]
# ### Explore the Target Variable (Y)

# %%
pheno = pd.DataFrame(dataset.phenotypic)
pheno.head()
# Out:
#   participant_id    Age AgeGroup Child_Adult Gender Handedness
# 0   sub-pixar123  27.06    Adult       adult      F          R
# 1   sub-pixar124  33.44    Adult       adult      M          R
# 2   sub-pixar125  31.00    Adult       adult      M          R
# 3   sub-pixar126  19.00    Adult       adult      F          R
# 4   sub-pixar127  23.00    Adult       adult      F          R

# %%
# INFO

# Display the shape of the data
print("Data Shape:")
print(pheno.shape)

# Check for any duplicate entries in the data.
print('')
print("Duplicate Values:")
print('(',pheno.duplicated().sum(),')')


# Display the data types of the columns
print("\nData Types:")
print(pheno.dtypes.value_counts())

# Check for missing values
missing_columns = pheno.columns[pheno.isnull().any()]
if missing_columns.size > 0:
    missing_values = pheno[missing_columns].isnull().sum()
    missing_percentage = (missing_values / len(pheno)) * 100

    # Combine missing_values and missing_percentage into a single DataFrame
    missing_data = pd.concat([missing_values, missing_percentage], axis=1, keys=['Total', 'Percent'])

    # Sort the missing_data DataFrame by Total column in descending order
    missing_data = missing_data.sort_values(by='Total', ascending=False)

    # Print missing data
    print("\nMissing Data:")
    print(missing_data.to_string())
else:
    print("\nNo Missing Values Found")
# Out:
# Data Shape:
# (155, 6)
#
# Duplicate Values:
# ( 0 )
#
# Data Types:
# object     5
# float64    1
# Name: count, dtype: int64
#
# No Missing Values Found

# %%
pheno.columns
# Out:
# Index(['participant_id', 'Age', 'AgeGroup', 'Child_Adult', 'Gender',
#        'Handedness'],
#       dtype='object')

# %%
pheno[['participant_id', 'Age', 'Child_Adult', 'Gender']].sample(10)
# Out:
#     participant_id        Age Child_Adult Gender
# 23    sub-pixar146  18.000000       adult      M
# 80    sub-pixar048   5.990000       child      M
# 53    sub-pixar021   4.364134       child      F
# 13    sub-pixar136  25.000000       adult      F
# 152   sub-pixar120  11.480000       child      F
# 38    sub-pixar006   3.605749       child      F
# 124   sub-pixar092   8.480000       child      M
# 135   sub-pixar103  10.550000       child      M
# 56    sub-pixar024   4.057495       child      M
# 10    sub-pixar133  21.000000       adult      M

# %%
sex = pheno['Gender']

print('Number of classes:',sex.unique())

sns.set_style("white")
sns.set_palette("muted")
sns.countplot(x= sex)

print(sex.value_counts())
# Out:
# Number of classes: ['F' 'M']
# Gender
# F    84
# M    71
# Name: count, dtype: int64

# %% [markdown]
# **AGE DISTRIBUTION**

# %%
age = pheno['Age']

sns.set_style("dark")
sns.set_palette("dark")
sns.histplot(age)

#skewness and kurtosis
print("Asymmetry: %f" % age.skew())
print("Kurtosis: %f" % age.kurt())
# Out:
# Asymmetry: 1.544492
# Kurtosis: 1.425876

# %%
# Group by column
diagnosis = pheno.groupby('Child_Adult')

# Calculate descriptive statistics
diagnosis['Age'].describe()
# Out:
#              count       mean       std        min       25%    50%      75%  \
# Child_Adult
# adult         33.0  24.772727  5.308521  18.000000  21.00000  23.00  28.0000
# child        122.0   6.709461  2.330938   3.518138   4.89521   5.98   8.3975
#
#               max
# Child_Adult
# adult        39.0
# child        12.3

# %% [markdown]
# ### Probabilistic Atlas
# ![image-3.png](attachment:image-3.png)

# %%
dim = 64
difumo = datasets.fetch_atlas_difumo(
    dimension=dim, resolution_mm=2, legacy_format=False
)

atlas_filename = difumo.maps
# Out:
# Dataset created in /root/nilearn_data/difumo_atlases
#
# Downloading data from https://osf.io/pqu9r/download ...
#  ...done. (3 seconds, 0 min)
# Extracting data from /root/nilearn_data/difumo_atlases/0fd53859aa9fed124e741c85ec45c705/download..... done.
# Downloading data from https://osf.io/4k9bf/download ...
#  ...done. (2 seconds, 0 min)

# %%
from nilearn import image, plotting

# First plot the map for the PCC: index 3 in the atlas
display = plotting.plot_stat_map(
    image.index_img(atlas_filename, 3),
    colorbar=True,
    title="PCC in Difumo atlas",
)

plotting.show()

# %%
difumo.labels
# Out:
#     component                       difumo_names     yeo_networks7  \
# 0           1            Superior frontal sulcus          DefaultB
# 1           2                     Fusiform gyrus  No network found
# 2           3         Calcarine cortex posterior           VisCent
# 3           4         Cingulate cortex posterior          DefaultB
# 4           5  Parieto-occipital sulcus superior             ContA
# ..        ...                                ...               ...
# 59         60                             Cuneus           VisCent
# 60         61              Middle temporal gyrus          DefaultB
# 61         62             Superior frontal gyrus          DefaultB
# 62         63                     Central sulcus           SomMotA
# 63         64                            Caudate  No network found
#
#       yeo_networks17        gm        wm       csf
# 0           DefaultA  0.689996  0.185709  0.116884
# 1   No network found  0.844733  0.021026  0.133789
# 2            VisPeri  0.601768  0.302067  0.091297
# 3           DefaultA  0.740086  0.140368  0.119567
# 4              ContC  0.640157  0.241492  0.117826
# ..               ...       ...       ...       ...
# 59           VisPeri  0.627179  0.269783  0.103005
# 60          DefaultB  0.726527  0.149595  0.107329
# 61          DefaultB  0.651182  0.062243  0.224067
# 62           SomMotB  0.578502  0.291674  0.109244
# 63  No network found  0.703295  0.260386  0.036332
#
# [64 rows x 7 columns]

# %% [markdown]
# ### Extract features with nilearn masker
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Compute a correlation matrix, representing regional coactivation between regions and extract signals from a brain parcellation

# %%
from nilearn.maskers import MultiNiftiMapsMasker
from nilearn.connectome import ConnectivityMeasure

# create masker using MultiNiftiMapsMasker to extract functional data within
# atlas parcels from multiple subjects using parallelization to speed up the
# # computation
masker = MultiNiftiMapsMasker(
    maps_img=atlas_filename,
    standardize='zscore_sample',
    standardize_confounds='zscore_sample',
    memory='nilearn_cache',
    n_jobs=2, verbose=0
)

# ConenctivityMeasure from Nilearn uses simple 'correlation' to compute
# connectivity matrices for all subjects in a list
connectome_measure = ConnectivityMeasure(
    kind='correlation', vectorize=True, discard_diagonal=True)

# %%
# METHOD 2

# extract time series from all subjects
#time_series = masker.fit_transform(data, confounds=data_confounds)

# calculate correlation matrices across subjects and display
#correlation_matrices = connectome_measure.fit_transform(time_series)

# %%
data[:4]
# Out:
# ['/root/nilearn_data/development_fmri/development_fmri/sub-pixar123_task-pixar_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/root/nilearn_data/development_fmri/development_fmri/sub-pixar124_task-pixar_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/root/nilearn_data/development_fmri/development_fmri/sub-pixar125_task-pixar_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/root/nilearn_data/development_fmri/development_fmri/sub-pixar126_task-pixar_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz']

# %% [markdown]
# **Extract fMRI connectivity features from every subject.**

# %%
# all_features = [connectome_measure.fit_transform([masker.fit_transform(sub, confounds=confounds[i])])[0] for i, sub in enumerate(data)]

# %%
# Let's save the data to disk

# np.savez_compressed('Age_Classf_featuress.npz',a = all_features)

# %%
# Path to the file in the Kaggle input directory
feat_file = '/kaggle/input/age-classf-featuress/Age_Classf_featuress.npz'

# Load the features
X_features = np.load(feat_file)['a']

# Print the shape of the features
print('Features shape:', X_features.shape)
# Out:
# Features shape: (155, 2016)

# %%
# Create the plot
plt.figure(figsize=(6, 4))
plt.imshow(X_features, aspect='auto', cmap='viridis', interpolation='nearest')

# Add colorbar
plt.colorbar(label='Correlation')

# Add title and labels
plt.title('Feature Matrix', fontsize=14)
plt.xlabel('Features', fontsize=12)
plt.ylabel('Subjects', fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Prepare data for machine learning

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()
y_target = label_encoder.fit_transform(pheno['Gender'])

# %%
# Print label encoding mapping
print("Label Encoding Mapping:")
for label, encoding in zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)):
    print(f"{label}: {encoding}")
# Out:
# Label Encoding Mapping:
# F: 0
# M: 1

# %%
# Separate features and target
y = y_target
x = X_features


x = torch.tensor(x, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).view(-1, 1)

# %%
# Constants
BATCH_SIZE = 32
TEST_SIZE = 0.25
RANDOM_STATE = 42

# Split into train/test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

# Move data to the appropriate device (DirectML, CUDA, or CPU)
x_train, y_train, x_test, y_test = [t.to(device) for t in [x_train, y_train, x_test, y_test]]

# DataLoader creation
train_dataset = TensorDataset(x_train, y_train)
test_dataset = TensorDataset(x_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
#import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming `device` is already defined and is a torch.device object
# Convert tensors to NumPy arrays by first moving them to CPU
y_train_cpu = y_train.cpu().numpy()
y_test_cpu = y_test.cpu().numpy()

# Plot histograms
sns.histplot(y_train_cpu, label='train', kde=True)
sns.histplot(y_test_cpu, label='test', kde=True)
plt.legend()
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of Target Variable')
plt.show()

# Print the size of the training and test sets
print('training:', len(x_train), 'testing:', len(x_test))
# Out:
# training: 116 testing: 39

# %% [markdown]
# ## **Non-Linear Model**

# %%
labels = difumo.labels["difumo_names"]

feature_mapping = {}
count = 1
for i in range(64):
    for j in range(i+1, 64):
        feature_name = f'{labels[i]} - {labels[j]}'
        feature_mapping[count] = {'name': feature_name, 'index': count}
        count += 1

# Convert the feature_mapping dictionary to a DataFrame
feature_mapping_df = pd.DataFrame.from_dict(feature_mapping, orient='index')

# Reset the index to make the 'index' column a regular column
feature_mapping_df.reset_index(inplace=True)

# Set column names
feature_mapping_df.columns = ['Feature Index', 'Feature Name', 'Feature Details']

# Drop columns
feature_mapping_df.drop(columns=['Feature Details'], inplace=True)

# Print the feature mapping DataFrame

feature_mapping_df.sample(5)
# Out:
#       Feature Index                                       Feature Name
# 2012           2013                    Middle temporal gyrus - Caudate
# 1113           1114  Superior fornix and isthmus - Anterior Cingula...
# 1274           1275                                  Putamen - Caudate
# 1564           1565  Precentral gyrus medial - Intraparietal sulcus RH
# 1772           1773  Lateral occipital cortex - Inferior frontal gyrus

# %%
# Assuming you have labels from difumo
labels = difumo.labels["difumo_names"]

# Generate feature names and indices
feature_names = [f'{labels[i]} - {labels[j]}' for i in range(64) for j in range(i + 1, 64)]
feature_indices = list(range(1, len(feature_names) + 1))

# Create a DataFrame
feature_mapping_df = pd.DataFrame({
    'Feature Index': feature_indices,
    'Feature Name': feature_names
})

# Display a sample of the feature mapping DataFrame
print(feature_mapping_df.head(5))
# Out:
#    Feature Index                                       Feature Name
# 0              1           Superior frontal sulcus - Fusiform gyrus
# 1              2  Superior frontal sulcus - Calcarine cortex pos...
# 2              3  Superior frontal sulcus - Cingulate cortex pos...
# 3              4  Superior frontal sulcus - Parieto-occipital su...
# 4              5   Superior frontal sulcus - Insula antero-superior

# %% [markdown]
# ### **Run the Classification Model**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import optuna
import numpy as np
from sklearn.metrics import accuracy_score, roc_auc_score
from torch.utils.data import DataLoader

# Classification Model Definition
class ClassificationModel(nn.Module):
    def __init__(self, input_dim, hidden_layers, dropout_rate, activation_fn, weight_init):
        super(ClassificationModel, self).__init__()
        layers = []
        last_dim = input_dim

        # Hidden layers
        for hidden_dim in hidden_layers:
            layers.append(nn.Linear(last_dim, hidden_dim))
            layers.append(nn.BatchNorm1d(hidden_dim))
            
            # Activation function
            if activation_fn == 'relu':
                layers.append(nn.ReLU())
            elif activation_fn == 'leaky_relu':
                layers.append(nn.LeakyReLU())
            elif activation_fn == 'tanh':
                layers.append(nn.Tanh())

            layers.append(nn.Dropout(dropout_rate))
            last_dim = hidden_dim

        # Output layer (Binary classification)
        layers.append(nn.Linear(last_dim, 1))

        # Optionally apply weight initialization
        self.apply(weight_init)

        # Sigmoid activation for binary classification
        layers.append(nn.Sigmoid())
        
        self.network = nn.Sequential(*layers)

    def forward(self, x):
        return self.network(x)

# Define different weight initialization strategies
def weight_init(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        nn.init.zeros_(m.bias)

# Hyperparameter Optimization Function using Optuna
def objective(trial):
    # Suggest hyperparameters
    hidden_layers = trial.suggest_categorical('hidden_layers', [[256, 128], [512, 256, 128], [512, 256]])
    dropout_rate = trial.suggest_float('dropout_rate', 0.2, 0.5)
    lr = trial.suggest_loguniform('lr', 1e-5, 1e-2)
    weight_decay = trial.suggest_loguniform('weight_decay', 1e-6, 1e-3)
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128])
    patience = trial.suggest_int('patience', 5, 15)
    activation_fn = trial.suggest_categorical('activation_fn', ['relu', 'leaky_relu', 'tanh'])
    optimizer_name = trial.suggest_categorical('optimizer', ['AdamW', 'SGD', 'Adam'])
    scheduler_name = trial.suggest_categorical('scheduler', ['CosineAnnealingLR', 'StepLR', 'ReduceLROnPlateau'])
    clip_grad = trial.suggest_float('clip_grad', 0.5, 5.0)  # Clip gradients between 0.5 and 5.0

    # Model initialization
    model = ClassificationModel(input_dim=x_train.shape[1], hidden_layers=hidden_layers,
                                dropout_rate=dropout_rate, activation_fn=activation_fn, weight_init=weight_init).to(device)

    # Optimizer selection
    if optimizer_name == 'AdamW':
        optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    elif optimizer_name == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay, momentum=0.9)
    elif optimizer_name == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    # Loss function: Experiment with BCEWithLogitsLoss for better numerical stability
    criterion = nn.BCEWithLogitsLoss()

    # Scheduler selection
    if scheduler_name == 'CosineAnnealingLR':
        scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=MAX_EPOCHS)
    elif scheduler_name == 'StepLR':
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    elif scheduler_name == 'ReduceLROnPlateau':
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.1)

    # DataLoader with updated batch size
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    # Training loop with early stopping
    best_loss = float('inf')
    no_improvement = 0

    for epoch in range(MAX_EPOCHS):
        model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), clip_grad)

            optimizer.step()
            running_loss += loss.item()

        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                val_loss += criterion(outputs, labels).item()

        val_loss /= len(test_loader)
        scheduler.step(val_loss) if scheduler_name == 'ReduceLROnPlateau' else scheduler.step()

        # Early stopping
        if val_loss < best_loss - 1e-3:
            best_loss = val_loss
            no_improvement = 0
        else:
            no_improvement += 1

        if no_improvement >= patience:
            break

    return val_loss

# Hyperparameter Optimization using Optuna
MAX_EPOCHS = 1000  # Define maximum epochs
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=1000)  # Conduct 100 trials for optimization

# Retrieve the best hyperparameters
best_params = study.best_params
print(f"Best hyperparameters: {best_params}")
# Out:
# [I 2024-09-18 10:36:17,064] A new study created in memory with name: no-name-01790610-b84d-4424-a5f3-6b6f0e93b671
# [I 2024-09-18 10:36:17,211] Trial 0 finished with value: 0.6871870160102844 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.2614579212159555, 'lr': 1.0027371301436624e-05, 'weight_decay': 0.00021127009452675237, 'batch_size': 32, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'SGD', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 2.090710440754654}. Best is trial 0 with value: 0.6871870160102844.
# [I 2024-09-18 10:36:17,294] Trial 1 finished with value: 0.7174169421195984 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.3602578788104414, 'lr': 9.379697232183003e-05, 'weight_decay': 7.888970258569702e-06, 'batch_size': 128, 'patience': 13, 'activation_fn': 'relu', 'optimizer': 'SGD', 'scheduler': 'CosineAnnealingLR', 'clip_grad': 1.1218887237944661}. Best is trial 0 with value: 0.6871870160102844.
# [I 2024-09-18 10:36:17,584] Trial 2 finished with value: 0.6860822439193726 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.21710329046565524, 'lr': 0.00016705235453396775, 'weight_decay': 0.00014605150062332046, 'batch_size': 128, 'patience': 11, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.813835967635275}. Best is trial 2 with value: 0.6860822439193726.
# [I 2024-09-18 10:36:17,941] Trial 3 finished with value: 0.6828713417053223 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.2634723319496346, 'lr': 0.00035262101134392245, 'weight_decay': 0.0006641698715274757, 'batch_size': 64, 'patience': 15, 'activation_fn': 'relu', 'optimizer': 'AdamW', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 2.0789084273000333}. Best is trial 3 with value: 0.6828713417053223.
# [I 2024-09-18 10:36:18,391] Trial 4 finished with value: 0.671136349439621 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.2668585402487076, 'lr': 0.00014565503450410177, 'weight_decay': 0.000875885551452235, 'batch_size': 32, 'patience': 13, 'activation_fn': 'relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.825649485211677}. Best is trial 4 with value: 0.671136349439621.
# [I 2024-09-18 10:36:18,568] Trial 5 finished with value: 0.7203381061553955 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.22274350144450442, 'lr': 0.00010054944843347573, 'weight_decay': 7.778500605595211e-06, 'batch_size': 64, 'patience': 15, 'activation_fn': 'leaky_relu', 'optimizer': 'SGD', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 4.461260692589564}. Best is trial 4 with value: 0.671136349439621.
# [I 2024-09-18 10:36:18,868] Trial 6 finished with value: 0.6983135044574738 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.20975746400179462, 'lr': 0.009406052209733066, 'weight_decay': 1.560230872116967e-05, 'batch_size': 32, 'patience': 12, 'activation_fn': 'relu', 'optimizer': 'Adam', 'scheduler': 'CosineAnnealingLR', 'clip_grad': 3.0258638894805254}. Best is trial 4 with value: 0.671136349439621.
# [I 2024-09-18 10:36:19,356] Trial 7 finished with value: 0.6853179335594177 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.36370028814160726, 'lr': 1.7708461063380655e-05, 'weight_decay': 0.000383163558151917, 'batch_size': 64, 'patience': 11, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'CosineAnnealingLR', 'clip_grad': 2.406875473777134}. Best is trial 4 with value: 0.671136349439621.
# [I 2024-09-18 10:36:19,435] Trial 8 finished with value: 0.7196049690246582 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.4832680882796851, 'lr': 0.00014417238891789689, 'weight_decay': 8.047449859726961e-05, 'batch_size': 128, 'patience': 13, 'activation_fn': 'relu', 'optimizer': 'SGD', 'scheduler': 'StepLR', 'clip_grad': 3.7028946482514904}. Best is trial 4 with value: 0.671136349439621.
# [I 2024-09-18 10:36:19,499] Trial 9 finished with value: 0.7180107235908508 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.36858476301072673, 'lr': 2.5193090988735854e-05, 'weight_decay': 3.4895237129596866e-05, 'batch_size': 128, 'patience': 9, 'activation_fn': 'relu', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 4.870218223191938}. Best is trial 4 with value: 0.671136349439621.
# [I 2024-09-18 10:36:19,767] Trial 10 finished with value: 0.667090654373169 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.2982246909465468, 'lr': 0.0011975491873778934, 'weight_decay': 1.9002251826019998e-06, 'batch_size': 32, 'patience': 6, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 4.005648139060572}. Best is trial 10 with value: 0.667090654373169.
# [I 2024-09-18 10:36:19,946] Trial 11 finished with value: 0.6814396977424622 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.2991677856879461, 'lr': 0.001351456480841933, 'weight_decay': 1.9003516005556405e-06, 'batch_size': 32, 'patience': 5, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.937469770711656}. Best is trial 10 with value: 0.667090654373169.
# [I 2024-09-18 10:36:20,246] Trial 12 finished with value: 0.6701221764087677 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.30390511716379237, 'lr': 0.0012253062699369693, 'weight_decay': 1.0309281555481225e-06, 'batch_size': 32, 'patience': 8, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.782929317167394}. Best is trial 10 with value: 0.667090654373169.
# [I 2024-09-18 10:36:20,438] Trial 13 finished with value: 0.6798192262649536 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.4206487362314818, 'lr': 0.0016090424319108077, 'weight_decay': 1.0418064249454448e-06, 'batch_size': 32, 'patience': 8, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.364479311555101}. Best is trial 10 with value: 0.667090654373169.
# [I 2024-09-18 10:36:20,684] Trial 14 finished with value: 0.6621812283992767 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.3183975542370116, 'lr': 0.0013995604599550747, 'weight_decay': 2.9529149438008707e-06, 'batch_size': 32, 'patience': 5, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 4.34781830719949}. Best is trial 14 with value: 0.6621812283992767.
# [I 2024-09-18 10:36:20,888] Trial 15 finished with value: 0.6813681125640869 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3153473708028185, 'lr': 0.00433301333887426, 'weight_decay': 3.4880061674889416e-06, 'batch_size': 32, 'patience': 5, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 4.856179570765183}. Best is trial 14 with value: 0.6621812283992767.
# [I 2024-09-18 10:36:21,108] Trial 16 finished with value: 0.6681160628795624 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.40707247296558624, 'lr': 0.0005594067944044072, 'weight_decay': 3.7781770154890716e-06, 'batch_size': 32, 'patience': 6, 'activation_fn': 'leaky_relu', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 4.262793725792081}. Best is trial 14 with value: 0.6621812283992767.
# [I 2024-09-18 10:36:21,283] Trial 17 finished with value: 0.6671966314315796 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.3300802233728451, 'lr': 0.003013226388896796, 'weight_decay': 3.005336450162439e-05, 'batch_size': 32, 'patience': 6, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 0.5006680346033168}. Best is trial 14 with value: 0.6621812283992767.
# [I 2024-09-18 10:36:21,506] Trial 18 finished with value: 0.6765297055244446 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.4066243589254167, 'lr': 0.0005129480029487059, 'weight_decay': 3.3493225031903747e-06, 'batch_size': 32, 'patience': 7, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'CosineAnnealingLR', 'clip_grad': 4.386225739966368}. Best is trial 14 with value: 0.6621812283992767.
# [I 2024-09-18 10:36:21,749] Trial 19 finished with value: 0.6881566047668457 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.28901054017093863, 'lr': 0.009559772544211089, 'weight_decay': 8.962049000961332e-06, 'batch_size': 64, 'patience': 9, 'activation_fn': 'leaky_relu', 'optimizer': 'AdamW', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 3.3347439616484476}. Best is trial 14 with value: 0.6621812283992767.
# [I 2024-09-18 10:36:21,959] Trial 20 finished with value: 0.6746248006820679 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.33484675538538444, 'lr': 0.003322301176915553, 'weight_decay': 2.4696293465577072e-06, 'batch_size': 32, 'patience': 5, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 4.550870586785302}. Best is trial 14 with value: 0.6621812283992767.
# [I 2024-09-18 10:36:22,167] Trial 21 finished with value: 0.6658826172351837 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.3391589586496608, 'lr': 0.0021635576377252224, 'weight_decay': 3.333766254332634e-05, 'batch_size': 32, 'patience': 6, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 1.6910674070650513}. Best is trial 14 with value: 0.6621812283992767.
# [I 2024-09-18 10:36:22,362] Trial 22 finished with value: 0.6722330152988434 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.37484884765908133, 'lr': 0.0009207609284275079, 'weight_decay': 4.706480016801354e-05, 'batch_size': 32, 'patience': 6, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 1.4173287089645004}. Best is trial 14 with value: 0.6621812283992767.
# [I 2024-09-18 10:36:22,552] Trial 23 finished with value: 0.6872351467609406 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.3398713672380196, 'lr': 0.0021319806505040125, 'weight_decay': 1.7563756192715306e-05, 'batch_size': 32, 'patience': 7, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 1.4662317358998402}. Best is trial 14 with value: 0.6621812283992767.
# [I 2024-09-18 10:36:22,759] Trial 24 finished with value: 0.669430136680603 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.24931877140042524, 'lr': 0.0007365186954677374, 'weight_decay': 5.69261745182607e-06, 'batch_size': 32, 'patience': 6, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.36035571594483}. Best is trial 14 with value: 0.6621812283992767.
# [I 2024-09-18 10:36:22,957] Trial 25 finished with value: 0.6628140211105347 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.2834680117087003, 'lr': 0.004455116485985154, 'weight_decay': 1.319142041657481e-05, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.4077814570704237}. Best is trial 14 with value: 0.6621812283992767.
# [I 2024-09-18 10:36:23,255] Trial 26 finished with value: 0.6480632126331329 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.39045215429305835, 'lr': 0.004149870920741678, 'weight_decay': 1.6996143906730395e-05, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.362696353043174}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:23,454] Trial 27 finished with value: 0.6560966074466705 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.4416355110643697, 'lr': 0.004980398992055309, 'weight_decay': 1.57062863090091e-05, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.0858371615019453}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:23,724] Trial 28 finished with value: 0.6530168652534485 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.462203850069371, 'lr': 0.0050611623399236015, 'weight_decay': 8.134088664949061e-05, 'batch_size': 128, 'patience': 10, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 3.0232610157556223}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:23,863] Trial 29 finished with value: 0.6701975464820862 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.4771996234663993, 'lr': 0.006077373686111191, 'weight_decay': 9.39427194560983e-05, 'batch_size': 128, 'patience': 10, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 2.9885627956951084}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:24,063] Trial 30 finished with value: 0.6635729074478149 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.46087984487507655, 'lr': 0.0063628891326337755, 'weight_decay': 0.00028473685784804613, 'batch_size': 128, 'patience': 9, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 2.5700701471365055}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:24,213] Trial 31 finished with value: 0.6652600765228271 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.4429830196314358, 'lr': 0.0026578973273843945, 'weight_decay': 6.458604651576775e-05, 'batch_size': 128, 'patience': 10, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 3.2883852004599965}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:24,480] Trial 32 finished with value: 0.6953834295272827 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.4325311723991988, 'lr': 0.005348254537760109, 'weight_decay': 0.0001569390466005505, 'batch_size': 128, 'patience': 11, 'activation_fn': 'tanh', 'optimizer': 'SGD', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 3.0418043609730816}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:24,670] Trial 33 finished with value: 0.6968575716018677 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.49547113892387573, 'lr': 0.00809900037616314, 'weight_decay': 2.260039060081541e-05, 'batch_size': 128, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'SGD', 'scheduler': 'CosineAnnealingLR', 'clip_grad': 1.9360688199644955}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:24,854] Trial 34 finished with value: 0.6875091195106506 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.38506433385604705, 'lr': 0.0037064106507164367, 'weight_decay': 1.0566069294147184e-05, 'batch_size': 64, 'patience': 9, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 2.7498864912847747}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:25,040] Trial 35 finished with value: 0.68265700340271 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.45714562556955, 'lr': 0.0021164208542039696, 'weight_decay': 6.082857353730532e-06, 'batch_size': 128, 'patience': 12, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 3.551065781565308}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:25,314] Trial 36 finished with value: 0.6747934222221375 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.409464795714946, 'lr': 0.0002805516750719218, 'weight_decay': 0.00010979285131918471, 'batch_size': 32, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'SGD', 'scheduler': 'StepLR', 'clip_grad': 2.636447299173484}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:25,554] Trial 37 finished with value: 0.6957968473434448 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.44890537210100506, 'lr': 0.006214059168542076, 'weight_decay': 4.57047412878524e-05, 'batch_size': 64, 'patience': 10, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'CosineAnnealingLR', 'clip_grad': 4.178371339856832}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:25,790] Trial 38 finished with value: 0.6881407201290131 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.3877684619477342, 'lr': 0.0017674223349975668, 'weight_decay': 2.3538186923949552e-05, 'batch_size': 32, 'patience': 11, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 2.327981780859547}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:25,988] Trial 39 finished with value: 0.6709222197532654 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.4304146211669639, 'lr': 0.003011192640316536, 'weight_decay': 0.0001934259241606582, 'batch_size': 128, 'patience': 12, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.111619320277684}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:26,280] Trial 40 finished with value: 0.6808792352676392 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.4654553713593571, 'lr': 0.00028846652622188353, 'weight_decay': 6.550248721393143e-05, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'CosineAnnealingLR', 'clip_grad': 3.6721204946433073}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:26,500] Trial 41 finished with value: 0.6771591305732727 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.27979736444420794, 'lr': 0.004938889802964744, 'weight_decay': 1.38332470862499e-05, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.450277336716946}. Best is trial 26 with value: 0.6480632126331329.
# [I 2024-09-18 10:36:26,790] Trial 42 finished with value: 0.6465511918067932 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.25206004108014135, 'lr': 0.004153360207443147, 'weight_decay': 1.1561416064740852e-05, 'batch_size': 32, 'patience': 9, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.8906332912845913}. Best is trial 42 with value: 0.6465511918067932.
# [I 2024-09-18 10:36:27,109] Trial 43 finished with value: 0.6235170364379883 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.3501022290199406, 'lr': 0.007262729569427783, 'weight_decay': 6.341222005317345e-06, 'batch_size': 32, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.7744946211749446}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:27,670] Trial 44 finished with value: 0.6741227507591248 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.3521471595888082, 'lr': 4.298891736335708e-05, 'weight_decay': 5.3034942325727065e-06, 'batch_size': 32, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.121507610671557}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:27,859] Trial 45 finished with value: 0.6602471470832825 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.23212069695897591, 'lr': 0.0078012322878574, 'weight_decay': 1.9492020365548565e-05, 'batch_size': 64, 'patience': 9, 'activation_fn': 'relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.862310192893933}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:28,391] Trial 46 finished with value: 0.6641747057437897 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.3915137471431468, 'lr': 0.003988731409915524, 'weight_decay': 1.0291465789871504e-05, 'batch_size': 32, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'SGD', 'scheduler': 'StepLR', 'clip_grad': 2.5720111128543093}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:28,824] Trial 47 finished with value: 0.6285505294799805 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3576796958222559, 'lr': 0.009706676983729446, 'weight_decay': 6.9943066592722286e-06, 'batch_size': 32, 'patience': 10, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.2326091487103774}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:29,091] Trial 48 finished with value: 0.6440343856811523 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3611908219056505, 'lr': 0.0073730031973593705, 'weight_decay': 6.964964714352807e-06, 'batch_size': 128, 'patience': 10, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.8320224177156037}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:29,356] Trial 49 finished with value: 0.6677581369876862 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3521126385479972, 'lr': 0.009309744960253429, 'weight_decay': 4.904807760874515e-06, 'batch_size': 32, 'patience': 11, 'activation_fn': 'relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.2168141301524873}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:29,731] Trial 50 finished with value: 0.6481515467166901 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.37037589261539705, 'lr': 0.007639800315661482, 'weight_decay': 6.683123358716875e-06, 'batch_size': 32, 'patience': 12, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.760416367710177}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:30,017] Trial 51 finished with value: 0.6730556190013885 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3672897244958324, 'lr': 0.006560860553372022, 'weight_decay': 7.073274003508283e-06, 'batch_size': 32, 'patience': 12, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.804559836210968}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:30,422] Trial 52 finished with value: 0.6338160634040833 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.37814501643983034, 'lr': 0.009409523016703652, 'weight_decay': 8.011348355040472e-06, 'batch_size': 32, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.869970214172519}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:30,806] Trial 53 finished with value: 0.6635966002941132 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.31480501354011536, 'lr': 0.00955740639298164, 'weight_decay': 1.1521366446447658e-05, 'batch_size': 32, 'patience': 15, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.180159088055465}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:31,204] Trial 54 finished with value: 0.668590247631073 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.398633170541094, 'lr': 1.1214360083267336e-05, 'weight_decay': 8.26323839520332e-06, 'batch_size': 32, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.5911392329591716}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:31,486] Trial 55 finished with value: 0.6916674673557281 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.35794517829866207, 'lr': 0.009942499099621232, 'weight_decay': 4.1134046556164315e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.5738154994132425}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:31,773] Trial 56 finished with value: 0.6346038579940796 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3791057375405362, 'lr': 0.0036539839613230975, 'weight_decay': 2.4488604029604148e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.9686447836145824}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:32,064] Trial 57 finished with value: 0.6839446127414703 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.34465329082682156, 'lr': 0.007228743123873951, 'weight_decay': 1.3632482394377368e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.8118344263757296}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:32,327] Trial 58 finished with value: 0.6806113719940186 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.37802971821371123, 'lr': 0.0026083573895924407, 'weight_decay': 2.188961885029799e-06, 'batch_size': 64, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.9003341171384815}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:32,746] Trial 59 finished with value: 0.6598322987556458 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.32942546732432676, 'lr': 6.8968270211317e-05, 'weight_decay': 1.6371563642594581e-06, 'batch_size': 32, 'patience': 15, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.9824295765171156}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:32,964] Trial 60 finished with value: 0.6596109867095947 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.35961914104776416, 'lr': 0.0034459835587037383, 'weight_decay': 2.7059582840091436e-06, 'batch_size': 128, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.3885264307914715}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:33,188] Trial 61 finished with value: 0.6521868407726288 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3786070142895157, 'lr': 0.004031114662908274, 'weight_decay': 4.587337286726886e-06, 'batch_size': 32, 'patience': 9, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 4.696580218730855}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:33,508] Trial 62 finished with value: 0.6865660548210144 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.2043980294337538, 'lr': 0.005492399536026228, 'weight_decay': 8.562731679334357e-06, 'batch_size': 32, 'patience': 10, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 4.136028366564943}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:33,891] Trial 63 finished with value: 0.6663195788860321 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.41726070060455966, 'lr': 0.007553966592198711, 'weight_decay': 1.2174480801540597e-05, 'batch_size': 32, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.2094428555061194}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:34,411] Trial 64 finished with value: 0.6720097959041595 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3964795483979308, 'lr': 0.004239874687118353, 'weight_decay': 3.258036473408915e-06, 'batch_size': 32, 'patience': 15, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.4355389357321213}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:34,626] Trial 65 finished with value: 0.6800905466079712 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.32967877525863876, 'lr': 0.0023619688747501546, 'weight_decay': 2.483051161623243e-05, 'batch_size': 32, 'patience': 9, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.1836228776678084}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:34,883] Trial 66 finished with value: 0.6950607001781464 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.36390726725013894, 'lr': 0.0031647622637390516, 'weight_decay': 1.5861294072193486e-05, 'batch_size': 32, 'patience': 11, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.905814649584835}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:35,169] Trial 67 finished with value: 0.6783481240272522 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.3489638840264408, 'lr': 0.0009396766178781206, 'weight_decay': 0.0005749314248255093, 'batch_size': 32, 'patience': 10, 'activation_fn': 'relu', 'optimizer': 'Adam', 'scheduler': 'CosineAnnealingLR', 'clip_grad': 3.8625869912882473}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:35,356] Trial 68 finished with value: 0.6592457890510559 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.323272526053705, 'lr': 0.001825597581136316, 'weight_decay': 7.180895509818174e-06, 'batch_size': 128, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.6976610360017226}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:35,633] Trial 69 finished with value: 0.6669890880584717 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.38288893603189167, 'lr': 0.005762149275540315, 'weight_decay': 3.833944042941534e-06, 'batch_size': 32, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'SGD', 'scheduler': 'StepLR', 'clip_grad': 2.487383314255404}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:35,987] Trial 70 finished with value: 0.6567187905311584 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.4023558892273013, 'lr': 0.006720121311654461, 'weight_decay': 9.43183692208309e-06, 'batch_size': 32, 'patience': 9, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 0.5948629748404421}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:36,314] Trial 71 finished with value: 0.6646269857883453 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3745152832005537, 'lr': 0.008282228937071307, 'weight_decay': 7.27998145904965e-06, 'batch_size': 32, 'patience': 12, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.751973162258607}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:36,599] Trial 72 finished with value: 0.6292765140533447 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.37116540339581344, 'lr': 0.004737224416020796, 'weight_decay': 6.055590147323532e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.0456059601032885}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:36,975] Trial 73 finished with value: 0.6514039635658264 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3407333450951296, 'lr': 0.0046407592397941485, 'weight_decay': 4.808153097278958e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.9495658430062024}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:37,335] Trial 74 finished with value: 0.6776485741138458 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.35802748670260276, 'lr': 0.00019820724573154, 'weight_decay': 5.778989896497797e-06, 'batch_size': 32, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.2813030517088633}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:37,616] Trial 75 finished with value: 0.6655820906162262 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.41322693670796534, 'lr': 0.005630969121685681, 'weight_decay': 1.8486791747216107e-05, 'batch_size': 32, 'patience': 10, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.0979699696593177}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:37,781] Trial 76 finished with value: 0.6704528331756592 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.39504262549734476, 'lr': 0.002898703273041024, 'weight_decay': 1.312335374273786e-05, 'batch_size': 128, 'patience': 10, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.486611635289912}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:38,003] Trial 77 finished with value: 0.6750732660293579 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.30867663174877047, 'lr': 0.0036212151198157924, 'weight_decay': 1.0015508829902783e-05, 'batch_size': 64, 'patience': 15, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'CosineAnnealingLR', 'clip_grad': 3.628005591145783}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:38,300] Trial 78 finished with value: 0.6571635901927948 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.42435617111105856, 'lr': 0.008466991114110966, 'weight_decay': 3.089440181593958e-06, 'batch_size': 32, 'patience': 11, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 1.9657548900175392}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:38,807] Trial 79 finished with value: 0.6584056615829468 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.38744563595931036, 'lr': 0.0047791601983893026, 'weight_decay': 6.170555292658724e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'SGD', 'scheduler': 'StepLR', 'clip_grad': 2.293115827635212}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:39,081] Trial 80 finished with value: 0.6545514464378357 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.2544176651795649, 'lr': 0.001457267153410221, 'weight_decay': 2.868764221632972e-05, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.4714153567737576}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:39,559] Trial 81 finished with value: 0.6428113579750061 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3720781097920925, 'lr': 0.006895934956042447, 'weight_decay': 6.473816561110527e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.6896558443093244}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:39,959] Trial 82 finished with value: 0.6431120038032532 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3665305663641313, 'lr': 0.006620457196350196, 'weight_decay': 9.016511143289092e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.0099957268196342}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:40,368] Trial 83 finished with value: 0.6732231080532074 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3722534667469491, 'lr': 0.006692681413959607, 'weight_decay': 3.9483759730017425e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.6478873143545916}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:40,667] Trial 84 finished with value: 0.6709836721420288 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.36425324905653234, 'lr': 0.008520575354727637, 'weight_decay': 8.946640963697483e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.841491197154737}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:41,223] Trial 85 finished with value: 0.6368298828601837 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.34871018549345545, 'lr': 0.009735561740716759, 'weight_decay': 2.546271611592923e-06, 'batch_size': 32, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.0084411545581435}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:41,537] Trial 86 finished with value: 0.6617350578308105 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.34794737473071935, 'lr': 0.00983772987274453, 'weight_decay': 2.394438111487889e-06, 'batch_size': 128, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.007541819659603}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:41,913] Trial 87 finished with value: 0.6764369010925293 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.33605704730072894, 'lr': 0.006813836181643642, 'weight_decay': 1.4142570277919769e-06, 'batch_size': 32, 'patience': 14, 'activation_fn': 'relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.144024407779337}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:42,256] Trial 88 finished with value: 0.6276861727237701 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.35519549774081405, 'lr': 0.00555130839331275, 'weight_decay': 1.9698654585499898e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.6548423821487273}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:42,538] Trial 89 finished with value: 0.644519716501236 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3542286272051916, 'lr': 0.005583013757601907, 'weight_decay': 1.9140054664908144e-06, 'batch_size': 32, 'patience': 12, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.4981731391963207}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:42,864] Trial 90 finished with value: 0.6747639775276184 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.38095934635831125, 'lr': 0.0004073514578248687, 'weight_decay': 1.0650690736238143e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.25903077648905}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:43,223] Trial 91 finished with value: 0.6649947464466095 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3687965922199953, 'lr': 0.007901626877772157, 'weight_decay': 2.093715813745291e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.6880631372173918}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:43,626] Trial 92 finished with value: 0.6608642637729645 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3440687040486069, 'lr': 0.006185322721728953, 'weight_decay': 2.777079522242055e-06, 'batch_size': 32, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.9910604472843616}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:43,910] Trial 93 finished with value: 0.6461491286754608 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3613310752965868, 'lr': 0.004829560227446631, 'weight_decay': 4.6556587749441604e-06, 'batch_size': 32, 'patience': 12, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.290918851472952}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:44,197] Trial 94 finished with value: 0.6604759991168976 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.35258293221159115, 'lr': 0.00996726321932874, 'weight_decay': 3.5306708477991313e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.8085468885511524}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:44,419] Trial 95 finished with value: 0.6644057035446167 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3734107362000345, 'lr': 0.007275767192104048, 'weight_decay': 5.364731989834067e-06, 'batch_size': 64, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'CosineAnnealingLR', 'clip_grad': 3.085719421925925}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:44,588] Trial 96 finished with value: 0.6623059511184692 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.33312466818416187, 'lr': 0.008752182349211905, 'weight_decay': 4.188455682897165e-06, 'batch_size': 128, 'patience': 14, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.556482495692574}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:44,989] Trial 97 finished with value: 0.6736060082912445 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.32017643685083785, 'lr': 0.005447689816685727, 'weight_decay': 7.82552428045181e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 2.9634261614179995}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:45,345] Trial 98 finished with value: 0.696127325296402 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3662712289715055, 'lr': 0.003665344765234009, 'weight_decay': 1.6599236818878017e-06, 'batch_size': 32, 'patience': 15, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.7079408103438776}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:45,627] Trial 99 finished with value: 0.6662352085113525 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.38249042380220877, 'lr': 0.006435989040467049, 'weight_decay': 6.346445488594947e-06, 'batch_size': 32, 'patience': 12, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 2.3935112881892477}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:46,112] Trial 100 finished with value: 0.6610085666179657 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.35802021174520254, 'lr': 0.007647989795408229, 'weight_decay': 1.163039363154617e-06, 'batch_size': 32, 'patience': 15, 'activation_fn': 'relu', 'optimizer': 'SGD', 'scheduler': 'StepLR', 'clip_grad': 4.508596816788334}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:46,404] Trial 101 finished with value: 0.7007416784763336 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.352486276416584, 'lr': 0.005620479277996011, 'weight_decay': 1.8342002180933438e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.518464039425365}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:46,678] Trial 102 finished with value: 0.6383752822875977 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3423308009997181, 'lr': 0.0045223927121097705, 'weight_decay': 2.5548556008194825e-06, 'batch_size': 32, 'patience': 12, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.2014399209415423}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:46,967] Trial 103 finished with value: 0.6617719531059265 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.34198453218521907, 'lr': 0.00418562251077803, 'weight_decay': 2.7931843729321753e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.006636158954165}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:47,241] Trial 104 finished with value: 0.6457682847976685 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3280946223043012, 'lr': 0.008825157556244289, 'weight_decay': 2.5769693495280773e-06, 'batch_size': 32, 'patience': 12, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 1.7602771797392334}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:47,578] Trial 105 finished with value: 0.6518997251987457 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.37516845097886564, 'lr': 0.004786910655504602, 'weight_decay': 2.2315716256966823e-06, 'batch_size': 32, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.2217891168766357}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:47,847] Trial 106 finished with value: 0.6598286032676697 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3914128407379773, 'lr': 0.006945918744407812, 'weight_decay': 3.447719215681671e-06, 'batch_size': 128, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.611544775791336}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:48,227] Trial 107 finished with value: 0.6667645871639252 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.368086268534767, 'lr': 0.003079215916230893, 'weight_decay': 1.3989854625206147e-06, 'batch_size': 32, 'patience': 11, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.8461430752380794}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:48,856] Trial 108 finished with value: 0.6613978743553162 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3607514746840553, 'lr': 0.00592653633305579, 'weight_decay': 5.360686677573791e-06, 'batch_size': 32, 'patience': 14, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.220302255818675}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:49,176] Trial 109 finished with value: 0.6810945570468903 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3374712761325277, 'lr': 0.0026157107946527727, 'weight_decay': 7.6067378009496614e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 3.37431186636826}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:49,389] Trial 110 finished with value: 0.6849371194839478 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3463834209518861, 'lr': 0.008222417237643952, 'weight_decay': 3.147915557650782e-06, 'batch_size': 64, 'patience': 11, 'activation_fn': 'leaky_relu', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 1.8186878916485893}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:49,719] Trial 111 finished with value: 0.6770851314067841 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.35417403458931296, 'lr': 0.005022645653980717, 'weight_decay': 1.9905347450007013e-06, 'batch_size': 32, 'patience': 12, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.394743355002453}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:50,420] Trial 112 finished with value: 0.6375917494297028 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.40277326898289395, 'lr': 0.005865912389889604, 'weight_decay': 4.232472299516517e-06, 'batch_size': 32, 'patience': 12, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.7736830611609435}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:50,671] Trial 113 finished with value: 0.6592706143856049 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3792070122692983, 'lr': 0.007010165447990902, 'weight_decay': 4.5799664919009e-06, 'batch_size': 32, 'patience': 10, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 2.7792789500418915}. Best is trial 43 with value: 0.6235170364379883.
# [I 2024-09-18 10:36:51,226] Trial 114 finished with value: 0.6364187002182007 and parameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3698791798233899, 'lr': 0.009939637880869833, 'weight_decay': 4.1941557538801845e-06, 'batch_size': 32, 'patience': 13, 'activation_fn': 'tanh', 'optimizer': 'Adam', 'scheduler': 'StepLR', 'clip_grad': 1.543659039062872}. Best is trial 43 with value: 0.6235170364379883.
# ...
# [I 2024-09-18 10:42:21,149] Trial 963 finished with value: 0.676260381937027 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.39761382115616933, 'lr': 0.00664720756691326, 'weight_decay': 1.794974232601566e-06, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.293626168995435}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:21,576] Trial 964 finished with value: 0.6804361343383789 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.39522356269736963, 'lr': 0.005284434881319804, 'weight_decay': 2.5186129606562624e-06, 'batch_size': 32, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.4404054050023904}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:21,940] Trial 965 finished with value: 0.6754758954048157 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3985730368962228, 'lr': 0.008867860267572296, 'weight_decay': 3.478907919983999e-06, 'batch_size': 32, 'patience': 8, 'activation_fn': 'leaky_relu', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.8318742192253903}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:22,256] Trial 966 finished with value: 0.6870306730270386 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3105023992484428, 'lr': 0.007679354488317119, 'weight_decay': 2.0721269524576917e-06, 'batch_size': 32, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 4.239740781050636}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:22,607] Trial 967 finished with value: 0.6648567318916321 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.38485417705534225, 'lr': 0.005987721504638089, 'weight_decay': 1.4775343233921736e-06, 'batch_size': 64, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 4.044931280997543}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:22,985] Trial 968 finished with value: 0.6874494850635529 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3283807896560877, 'lr': 0.009988694273950945, 'weight_decay': 1.014254820564973e-06, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.6658350002842655}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:23,410] Trial 969 finished with value: 0.6783280372619629 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3376091819843727, 'lr': 0.006901509198844993, 'weight_decay': 1.1830528081385065e-06, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.3450486386278717}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:23,837] Trial 970 finished with value: 0.6426911652088165 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.45320140155258604, 'lr': 0.008068566604133864, 'weight_decay': 1.7251868500839028e-06, 'batch_size': 32, 'patience': 6, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.5634058418696046}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:24,109] Trial 971 finished with value: 0.6809930801391602 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.38174791328730195, 'lr': 0.0054744279261681, 'weight_decay': 1.3012998722247774e-06, 'batch_size': 128, 'patience': 6, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.937495038593507}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:24,445] Trial 972 finished with value: 0.675978422164917 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.347251631430867, 'lr': 0.006216306236069353, 'weight_decay': 2.112157907264027e-06, 'batch_size': 32, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'CosineAnnealingLR', 'clip_grad': 4.503929250459251}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:24,798] Trial 973 finished with value: 0.6656703352928162 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.392600899663646, 'lr': 0.0071895603904637406, 'weight_decay': 1.5739040039583344e-06, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.7403954795476433}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:25,257] Trial 974 finished with value: 0.6344330608844757 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3821740596713686, 'lr': 0.009954405688599805, 'weight_decay': 1.926381172842291e-06, 'batch_size': 32, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.260236176769706}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:25,651] Trial 975 finished with value: 0.6820149421691895 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.34302031177752895, 'lr': 0.0004997669882162273, 'weight_decay': 2.4011632233896263e-06, 'batch_size': 32, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 3.825391913074384}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:26,118] Trial 976 finished with value: 0.6482485234737396 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3502523950852337, 'lr': 0.004647391572463112, 'weight_decay': 1.3027367652676998e-06, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 4.103414211203858}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:26,454] Trial 977 finished with value: 0.6813905835151672 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.39153301144719865, 'lr': 0.008084748650942174, 'weight_decay': 1.5832466862744284e-06, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.3969390582055463}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:26,812] Trial 978 finished with value: 0.6852096319198608 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3336115915090437, 'lr': 0.00875628418891981, 'weight_decay': 2.758035163945296e-06, 'batch_size': 32, 'patience': 7, 'activation_fn': 'relu', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 4.015867649444259}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:27,307] Trial 979 finished with value: 0.640365868806839 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3821721771770456, 'lr': 0.006708287375996597, 'weight_decay': 1.9103268733534437e-06, 'batch_size': 32, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.603843422672944}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:27,747] Trial 980 finished with value: 0.6769285202026367 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.4127778336466959, 'lr': 0.00018686522258469092, 'weight_decay': 2.3054710470797984e-06, 'batch_size': 32, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.461668284001051}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:28,097] Trial 981 finished with value: 0.6573294997215271 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.34682268762203694, 'lr': 0.005572096825124105, 'weight_decay': 1.3540428116828388e-06, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 2.5315156156856453}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:28,438] Trial 982 finished with value: 0.64411461353302 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.38198209760165774, 'lr': 0.007335470901135791, 'weight_decay': 3.183435168780316e-06, 'batch_size': 32, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.8892866688574177}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:28,844] Trial 983 finished with value: 0.6671517789363861 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3556575234285828, 'lr': 0.00865357690616158, 'weight_decay': 1.1584699912599147e-06, 'batch_size': 32, 'patience': 9, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.2160978829766296}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:29,123] Trial 984 finished with value: 0.6823858320713043 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.33995270347684947, 'lr': 0.006208975378219426, 'weight_decay': 1.6152757184075294e-06, 'batch_size': 32, 'patience': 6, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 4.175463685125336}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:29,523] Trial 985 finished with value: 0.6574762463569641 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.35549008477503974, 'lr': 0.007460203223179034, 'weight_decay': 1.9726722404569348e-06, 'batch_size': 32, 'patience': 9, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.6714000624451177}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:29,913] Trial 986 finished with value: 0.6751454174518585 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.38929806117188, 'lr': 0.004905697254293903, 'weight_decay': 1.7409736983321892e-06, 'batch_size': 32, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'ReduceLROnPlateau', 'clip_grad': 3.7992228472413103}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:30,256] Trial 987 finished with value: 0.6326501071453094 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.37709560784803725, 'lr': 0.00879059234068589, 'weight_decay': 2.5754319846690738e-06, 'batch_size': 32, 'patience': 8, 'activation_fn': 'leaky_relu', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.5457841323118817}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:30,752] Trial 988 finished with value: 0.6527990400791168 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3505725504594682, 'lr': 0.006429058703400451, 'weight_decay': 1.4865680678903705e-06, 'batch_size': 32, 'patience': 9, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.296639734728118}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:31,134] Trial 989 finished with value: 0.6523569524288177 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.36049615030592697, 'lr': 0.0023953785544648725, 'weight_decay': 2.1552948669485703e-06, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.924451782881178}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:31,388] Trial 990 finished with value: 0.6764073967933655 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.34310998790689745, 'lr': 0.007744753938184686, 'weight_decay': 1.3530903952050434e-06, 'batch_size': 64, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.7393544348483245}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:31,781] Trial 991 finished with value: 0.6674552261829376 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.38089486748418916, 'lr': 0.005638966670344355, 'weight_decay': 3.6457517341983717e-06, 'batch_size': 32, 'patience': 9, 'activation_fn': 'tanh', 'optimizer': 'SGD', 'scheduler': 'StepLR', 'clip_grad': 4.0058954452671545}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:32,228] Trial 992 finished with value: 0.6354890167713165 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3568776681894459, 'lr': 0.009921489876032145, 'weight_decay': 1.1828338957941694e-06, 'batch_size': 32, 'patience': 5, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.388420101021443}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:32,568] Trial 993 finished with value: 0.674921452999115 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.37710729472127674, 'lr': 0.007312099389225126, 'weight_decay': 1.787673538449141e-06, 'batch_size': 32, 'patience': 8, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 2.233436290389339}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:32,857] Trial 994 finished with value: 0.7020414471626282 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3972950924477832, 'lr': 0.006470864800983098, 'weight_decay': 1.0186019718156793e-06, 'batch_size': 128, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'CosineAnnealingLR', 'clip_grad': 4.279110469368385}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:33,304] Trial 995 finished with value: 0.6677513420581818 and parameters: {'hidden_layers': [256, 128], 'dropout_rate': 0.3266974992319222, 'lr': 0.004996705442332131, 'weight_decay': 1.5728686938757224e-06, 'batch_size': 32, 'patience': 9, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.4836163281566845}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:33,741] Trial 996 finished with value: 0.6592126786708832 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3609877764614874, 'lr': 0.008955814014213553, 'weight_decay': 2.5625292570209066e-06, 'batch_size': 32, 'patience': 6, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.8392505237671846}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:34,066] Trial 997 finished with value: 0.6494318842887878 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3491765575688379, 'lr': 0.004163906946220794, 'weight_decay': 2.1862940529449336e-06, 'batch_size': 32, 'patience': 7, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.6196726633561047}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:34,436] Trial 998 finished with value: 0.6880459189414978 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.3857124350411767, 'lr': 0.007828537932762076, 'weight_decay': 3.027035701117313e-06, 'batch_size': 32, 'patience': 9, 'activation_fn': 'relu', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.193851063533652}. Best is trial 580 with value: 0.6092232465744019.
# [I 2024-09-18 10:42:34,846] Trial 999 finished with value: 0.6473807394504547 and parameters: {'hidden_layers': [512, 256, 128], 'dropout_rate': 0.35469892216056675, 'lr': 0.006218571484345463, 'weight_decay': 1.8673533692819358e-06, 'batch_size': 32, 'patience': 9, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.277531507614164}. Best is trial 580 with value: 0.6092232465744019.
# Best hyperparameters: {'hidden_layers': [512, 256], 'dropout_rate': 0.3730925921461638, 'lr': 0.006666504653598233, 'weight_decay': 1.3380313578486322e-06, 'batch_size': 32, 'patience': 10, 'activation_fn': 'tanh', 'optimizer': 'AdamW', 'scheduler': 'StepLR', 'clip_grad': 3.6735982324719787}

# %%
# Model Training Function
def train_model(model, train_loader, test_loader, criterion, optimizer, scheduler, max_epochs, patience, clip_grad=None, scheduler_name=None):
    best_loss = float('inf')
    no_improvement = 0

    for epoch in range(max_epochs):
        model.train()
        running_loss = 0.0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            
            # Backward pass and optimization
            loss.backward()

            # Gradient clipping
            if clip_grad is not None:
                torch.nn.utils.clip_grad_norm_(model.parameters(), clip_grad)

            optimizer.step()
            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        # Validation step
        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                val_loss += criterion(outputs, labels).item()

        val_loss /= len(test_loader)
        running_loss /= len(train_loader)

        print(f"Epoch [{epoch+1}/{max_epochs}], Train Loss: {running_loss:.4f}, Val Loss: {val_loss:.4f}")

        # Update scheduler (if using ReduceLROnPlateau)
        if scheduler_name == 'ReduceLROnPlateau':
            scheduler.step(val_loss)
        else:
            scheduler.step()

        # Early stopping
        if val_loss < best_loss - 1e-3:
            best_loss = val_loss
            no_improvement = 0
        else:
            no_improvement += 1
        
        if no_improvement >= patience:
            print("Early stopping triggered")
            break

    return model

# Model Evaluation Function
def evaluate_model(model, test_loader):
    model.eval()
    all_outputs, all_labels = [], []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            all_outputs.append(outputs.cpu().numpy())
            all_labels.append(labels.cpu().numpy())

    all_outputs = np.concatenate(all_outputs)
    all_labels = np.concatenate(all_labels)

    # Calculate evaluation metrics
    auc_roc = roc_auc_score(all_labels, all_outputs)
    accuracy = accuracy_score(all_labels, np.round(all_outputs))
    return auc_roc, accuracy

# Initialize Model with the Best Hyperparameters
hidden_layers = best_params['hidden_layers']
dropout_rate = best_params['dropout_rate']
activation_fn = best_params['activation_fn']
lr = best_params['lr']
weight_decay = best_params['weight_decay']
optimizer_name = best_params['optimizer']
scheduler_name = best_params['scheduler']
clip_grad = best_params.get('clip_grad', None)  # Gradient clipping value if provided

model = ClassificationModel(input_dim=x_train.shape[1], hidden_layers=hidden_layers,
                            dropout_rate=dropout_rate, activation_fn=activation_fn, weight_init=weight_init).to(device)

# Select Optimizer
if optimizer_name == 'AdamW':
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
elif optimizer_name == 'SGD':
    optimizer = optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay, momentum=0.9)
elif optimizer_name == 'Adam':
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

# Loss Function
criterion = nn.BCEWithLogitsLoss()

# Select Scheduler
if scheduler_name == 'CosineAnnealingLR':
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=MAX_EPOCHS)
elif scheduler_name == 'StepLR':
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
elif scheduler_name == 'ReduceLROnPlateau':
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.1)

# Train the Model
train_loader = DataLoader(train_dataset, batch_size=best_params['batch_size'], shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=best_params['batch_size'], shuffle=False)
trained_model = train_model(model, train_loader, test_loader, criterion, optimizer, scheduler, max_epochs=MAX_EPOCHS, patience=best_params['patience'], clip_grad=clip_grad, scheduler_name=scheduler_name)
# Out:
# Epoch [1/1000], Train Loss: 0.7802, Val Loss: 0.6467
# Epoch [2/1000], Train Loss: 0.6883, Val Loss: 0.6320
# Epoch [3/1000], Train Loss: 0.6569, Val Loss: 0.6697
# Epoch [4/1000], Train Loss: 0.6380, Val Loss: 0.6610
# Epoch [5/1000], Train Loss: 0.6173, Val Loss: 0.6429
# Epoch [6/1000], Train Loss: 0.5947, Val Loss: 0.6542
# Epoch [7/1000], Train Loss: 0.5952, Val Loss: 0.6645
# Epoch [8/1000], Train Loss: 0.5820, Val Loss: 0.7059
# Epoch [9/1000], Train Loss: 0.5838, Val Loss: 0.6590
# Epoch [10/1000], Train Loss: 0.5702, Val Loss: 0.6552
# Epoch [11/1000], Train Loss: 0.5665, Val Loss: 0.6538
# Epoch [12/1000], Train Loss: 0.5562, Val Loss: 0.6546
# Early stopping triggered

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score

# Model Evaluation Function
def evaluate_model(model, test_loader):
    model.eval()
    all_outputs, all_labels = [], []
    
    # Inference loop
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            all_outputs.append(outputs.cpu().numpy())
            all_labels.append(labels.cpu().numpy())

    # Concatenate results
    all_outputs = np.concatenate(all_outputs)
    all_labels = np.concatenate(all_labels)

    # Threshold the outputs (since it's binary classification)
    predicted_labels = np.round(all_outputs)

    # Calculate evaluation metrics
    auc_roc = roc_auc_score(all_labels, all_outputs)  # AUC-ROC
    accuracy = accuracy_score(all_labels, predicted_labels)  # Accuracy
    precision = precision_score(all_labels, predicted_labels)  # Precision
    recall = recall_score(all_labels, predicted_labels)  # Recall
    f1 = f1_score(all_labels, predicted_labels)  # F1-score

    # Print metrics
    print(f"AUC-ROC: {auc_roc:.4f}")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")

    return auc_roc, accuracy, precision, recall, f1

# %%
# Evaluate the trained model on the test dataset
auc_roc, accuracy, precision, recall, f1 = evaluate_model(trained_model, test_loader)
# Out:
# AUC-ROC: 0.7105
# Accuracy: 0.6923
# Precision: 0.7000
# Recall: 0.7000
# F1-Score: 0.7000

# %%
# Save the model's state dict
torch.save(trained_model.state_dict(), 'Pytorch_Classifier_fMRI.pth')

# %%
import json

# Save hyperparameters
with open('Pytorch_Classifier_fMRI_hyperparameters.json', 'w') as f:
    json.dump(best_params, f)

# %%
metrics = {'AUC-ROC': auc_roc, 'Accuracy': accuracy, 'Precision': precision, 'Recall': recall, 'F1-Score': f1}
metric_names = list(metrics.keys())
metric_values = list(metrics.values())

plt.figure(figsize=(10, 6))
plt.bar(metric_names, metric_values, color=['skyblue', 'lightgreen', 'orange', 'purple', 'red'])
plt.title("Model Performance Metrics")
plt.ylabel("Score")
plt.ylim(0, 1)  # As all scores are in [0, 1]
for i, v in enumerate(metric_values):
    plt.text(i, v + 0.02, f"{v:.4f}", ha='center', fontsize=12)
plt.show()

# %%
from sklearn.metrics import confusion_matrix

# 2. Confusion Matrix
# Get model predictions and true labels
all_outputs = []
all_labels = []
trained_model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = trained_model(inputs)
        all_outputs.append(outputs.cpu().numpy())
        all_labels.append(labels.cpu().numpy())

all_outputs = np.concatenate(all_outputs)
all_labels = np.concatenate(all_labels)

# Convert probabilities to binary predictions (0 or 1)
predictions = np.round(all_outputs)

# Confusion Matrix
conf_matrix = confusion_matrix(all_labels, predictions)

# Plot Confusion Matrix
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=['Predicted 0', 'Predicted 1'], 
            yticklabels=['Female', 'Male'])
plt.title('Confusion Matrix')
plt.ylabel('True Labels')
plt.xlabel('Predicted Labels')
plt.show()

# %% [markdown]
# ### Feature Importance Analysis

# %%
# Feature importance
def perturbation_rank(model, x_test, y_test, feature_names, verbose=False):
    model.eval()
    baseline_loss = criterion(model(x_test), y_test).item()
    importance_scores = []

    for i in range(x_test.shape[1]):
        x_test_perturbed = x_test.clone()
        x_test_perturbed[:, i] = x_test_perturbed[torch.randperm(x_test_perturbed.size(0)), i]
        perturbed_loss = criterion(model(x_test_perturbed), y_test).item()
        importance = perturbed_loss - baseline_loss
        importance_scores.append(importance)

        if verbose:
            print(f"Feature {feature_names[i]} - Perturbed Loss: {perturbed_loss:.4f} - Importance: {importance:.4f}")

    importance_df = pd.DataFrame({
        'Feature': feature_names,
        'Importance': importance_scores
    }).sort_values(by='Importance', ascending=False).reset_index(drop=True)

    return importance_df


# Feature Importance
feature_names = feature_mapping_df['Feature Name'].tolist()
importance_df = perturbation_rank(trained_model, x_test, y_test, feature_names)

# %%
# Plot top 10 feature importances
top_10_feature_importances = importance_df.head(10)

plt.figure(figsize=(10, 8))
sns.barplot(x='Importance', y='Feature', data=top_10_feature_importances)
plt.title('Top 10 Feature Importances')
plt.xlabel('Importance Score')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()

# %%
importance_df.Feature
# Out:
# 0                           Planum polare - Lingual gyrus
# 1                   Cingulate gyrus mid-anterior - Cuneus
# 2             Transverse sinus - Inferior occipital gyrus
# 3               Calcarine sulcus anterior - Lingual gyrus
# 4            Inferior frontal sulcus - Precuneus anterior
#                               ...
# 2011    Fusiform gyrus posterior - Inferior occipital ...
# 2012    Insula antero-superior - Superior parietal lob...
# 2013    Cingulate cortex posterior - Superior occipita...
# 2014    Cerebellum Crus II - Superior parietal lobule ...
# 2015          Cingulate cortex posterior - Central sulcus
# Name: Feature, Length: 2016, dtype: object

# %%
# Feature Importance Visuals

difumo_labels = difumo.labels

roi_names = 'Planum polare|Lingual gyrus'
ft_link = difumo_labels[difumo_labels['difumo_names'].str.contains(roi_names, case=False)]

roi_index = ft_link.index.tolist()

ft_link['difumo_names']
# Out:
# 18             Planum polare
# 34    Lingual gyrus anterior
# 54             Lingual gyrus
# Name: difumo_names, dtype: object

# %%
from nilearn import image

# First plot the map for the Region of Interest: index (i) in the atlas
display = plotting.plot_stat_map(
    image.index_img(atlas_filename, 18 ),
    colorbar=False,
    title='Planum polare (Magma) - Lingual gyrus (Viridis)',
)

cmaps = [
    plotting.cm.black_red,
    plotting.cm.black_green,
    plotting.cm.black_pink,
]

for index, cmap in zip([54], cmaps ):
    display.add_overlay(image.index_img(atlas_filename, index), cmap='viridis')

plotting.show()

# %% [markdown]
# ### Visualize Regions of Interest

# %%
difumo_labels = difumo.labels
marker_labels = difumo_labels['difumo_names'].tolist() 

# grab center coordinates for probabilistic atlas
coords = plotting.find_probabilistic_atlas_cut_coords(
    maps_img=difumo.maps)

# %%
# Functions

def transform_df(df):
    """
    Transform the DataFrame by splitting the 'Feature Name' column into 'Marker1' and 'Marker2',
    dropping the original 'Feature Name' column, renaming 'Importance Score' to 'Correlation',
    and returning the transformed DataFrame.
    
    Parameters:
    df (pd.DataFrame): The input DataFrame with columns 'Feature Index', 'Feature Name', and 'Importance Score'.
    
    Returns:
    pd.DataFrame: The transformed DataFrame with columns 'Feature Index', 'Marker1', 'Marker2', and 'Correlation'.
    """
    
    # Ensure 'Feature Name' column exists
    if 'Feature' not in df.columns or 'Importance' not in df.columns:
        raise ValueError("Input DataFrame must contain 'Feature Name' and 'Importance Score' columns.")
    
    # Split `Feature Name` into `Marker1` and `Marker2`
    df[['Marker1', 'Marker2']] = df['Feature'].str.split(' - ', n=1, expand=True)
    
    # Drop the 'Feature Name' column
    df = df.drop(columns=['Feature'])
    
    
    return df



def visualize_connectome(df_sorted, coords, marker_labels, cmap_markers='viridis', cmap_edges='Paired'):
    # Ensure marker_labels is a list
    if isinstance(marker_labels, pd.Index):
        marker_labels = marker_labels.tolist()

    # Extract unique markers from the top rows
    unique_markers = pd.unique(df_sorted[['Marker1', 'Marker2']].values.ravel('K'))

    # Filter marker labels and coordinates to only include those in unique_markers
    filtered_indices = [i for i, label in enumerate(marker_labels) if label in unique_markers]
    filtered_coords = coords[filtered_indices]
    filtered_labels = [marker_labels[i] for i in filtered_indices]

    # Normalize correlations for color mapping
    norm = colors.Normalize(vmin=df_sorted['Importance'].min(), vmax=df_sorted['Importance'].max())
    cmap_markers = colormaps.get_cmap(cmap_markers)
    cmap_edges = colormaps.get_cmap(cmap_edges)

    # Create a Plotly figure
    fig = go.Figure()

    # Add nodes to the plot
    fig.add_trace(go.Scatter3d(
        x=filtered_coords[:, 0],
        y=filtered_coords[:, 1],
        z=filtered_coords[:, 2],
        mode='markers+text',
        marker=dict(size=8, color=[colors.to_hex(cmap_markers(norm(c))) for c in df_sorted['Importance']]),  # Use cmap for node colors
        text=filtered_labels,
        textfont=dict(color='white', size=13, family="Arial"),  # Larger font size
        textposition='middle right',  # Position labels on the right
        name='Markers'
    ))

    # Add edges to the plot
    for i, row in df_sorted.iterrows():
        marker1 = row['Marker1']
        marker2 = row['Marker2']
        correlation = row['Importance']

        marker1_idx = filtered_labels.index(marker1)
        marker2_idx = filtered_labels.index(marker2)

        fig.add_trace(go.Scatter3d(
            x=[filtered_coords[marker1_idx, 0], filtered_coords[marker2_idx, 0]],
            y=[filtered_coords[marker1_idx, 1], filtered_coords[marker2_idx, 1]],
            z=[filtered_coords[marker1_idx, 2], filtered_coords[marker2_idx, 2]],
            mode='lines',
            line=dict(color=colors.to_hex(cmap_edges(norm(correlation))), width=3),  # Use cmap for edge colors
            name=f"{marker1} - {marker2} ({correlation:.2f})"
        ))

    # Update layout
    fig.update_layout(
        title=dict(
            text='',
            x=0.5,  # Center the title
            y=0.95,  # Move the title slightly up to avoid overlap
            font=dict(size=26, color='white', family="Arial")
        ),
        paper_bgcolor='black',  # Black background for the entire figure
        plot_bgcolor='black',   # Black background for the plot area
        scene=dict(
            xaxis=dict(
                title=dict(text='X', font=dict(size=18, color='white')),
                showbackground=False,
                showgrid=True,
                gridcolor='rgba(50, 50, 50, 0.5)',  # Dark gray gridlines
                showline=True,
                linecolor='white',  # White axis lines
                showticklabels=False,
                zeroline=False
            ),
            yaxis=dict(
                title=dict(text='Y', font=dict(size=18, color='white')),
                showbackground=False,
                showgrid=True,
                gridcolor='rgba(50, 50, 50, 0.5)',  # Dark gray gridlines
                showline=True,
                linecolor='white',
                showticklabels=False,
                zeroline=False
            ),
            zaxis=dict(
                title=dict(text='Z', font=dict(size=18, color='white')),
                showbackground=False,
                showgrid=True,
                gridcolor='rgba(50, 50, 50, 0.5)',  # Dark gray gridlines
                showline=True,
                linecolor='white',
                showticklabels=False,
                zeroline=False
            )
        ),
        margin=dict(
            l=20,  # Adjusted margins for better spacing
            r=20,
            b=20,
            t=20
        ),
        width=600,  # Width of the plot
        height=400,  # Height of the plot
        showlegend=True,
        legend=dict(
            x=0.0,  # Center the title
            y=-0.2,  # Move the title slightly up to avoid overlap
            font=dict(size=10, color='white', family="Arial"),  # White font for the legend
            bgcolor='rgba(0, 0, 0, 0)',  # Transparent background for the legend
        )
    )
    
    if fig:
        fig.write_html('connectome_plot.html')
        print("Plot successfully saved as 'connectome_plot.html'")
    else:
        print("No figure returned.")

    # Show the plot
    fig.show()

# %%
marker_corr = transform_df(importance_df)
marker_corr
# Out:
#       Importance                       Marker1  \
# 0       0.004189                 Planum polare
# 1       0.002983  Cingulate gyrus mid-anterior
# 2       0.002937              Transverse sinus
# 3       0.002828     Calcarine sulcus anterior
# 4       0.002724       Inferior frontal sulcus
# ...          ...                           ...
# 2011   -0.002549      Fusiform gyrus posterior
# 2012   -0.003021        Insula antero-superior
# 2013   -0.003204    Cingulate cortex posterior
# 2014   -0.003357            Cerebellum Crus II
# 2015   -0.003704    Cingulate cortex posterior
#
#                                 Marker2
# 0                         Lingual gyrus
# 1                                Cuneus
# 2              Inferior occipital gyrus
# 3                         Lingual gyrus
# 4                    Precuneus anterior
# ...                                 ...
# 2011           Inferior occipital gyrus
# 2012  Superior parietal lobule anterior
# 2013          Superior occipital sulcus
# 2014  Superior parietal lobule anterior
# 2015                     Central sulcus
#
# [2016 rows x 3 columns]

# %%
visualize_connectome(marker_corr.head(4), coords, marker_labels, cmap_markers='Paired', cmap_edges='cool')
# Out:
# Plot successfully saved as 'connectome_plot.html'
# <div>                            <div id="eafd4d76-0d01-4822-b282-5266534be460" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eafd4d76-0d01-4822-b282-5266534be460")) {                    Plotly.newPlot(                        "eafd4d76-0d01-4822-b282-5266534be460",                        [{"marker":{"color":["#b15928","#1f78b4","#a6cee3","#a6cee3"],"size":8},"mode":"markers+text","name":"Markers","text":["Transverse sinus","Planum polare","Cingulate gyrus mid-anterior","Inferior occipital gyrus","Calcarine sulcus anterior","Lingual gyrus","Cuneus"],"textfont":{"color":"white","family":"Arial","size":13},"textposition":"middle right","x":[-19.677151186011372,54.37198922524624,0.2013299540077753,25.185454470776023,-12.32832434894803,19.530965926045596,1.9377971750032401],"y":[-79.16150149670565,0.39456772948824437,14.784165672144354,-81.66157663338369,-73.99620824948485,-68.49313859945124,-80.17590600302552],"z":[-21.139362980446258,2.149744643987077,36.31973960359849,-16.236828820584932,7.341546442399604,-9.619777515737866,15.493030839897756],"type":"scatter3d"},{"line":{"color":"#ff00ff","width":3},"mode":"lines","name":"Planum polare - Lingual gyrus (0.00)","x":[54.37198922524624,19.530965926045596],"y":[0.39456772948824437,-68.49313859945124],"z":[2.149744643987077,-9.619777515737866],"type":"scatter3d"},{"line":{"color":"#1de2ff","width":3},"mode":"lines","name":"Cingulate gyrus mid-anterior - Cuneus (0.00)","x":[0.2013299540077753,1.9377971750032401],"y":[14.784165672144354,-80.17590600302552],"z":[36.31973960359849,15.493030839897756],"type":"scatter3d"},{"line":{"color":"#14ebff","width":3},"mode":"lines","name":"Transverse sinus - Inferior occipital gyrus (0.00)","x":[-19.677151186011372,25.185454470776023],"y":[-79.16150149670565,-81.66157663338369],"z":[-21.139362980446258,-16.236828820584932],"type":"scatter3d"},{"line":{"color":"#00ffff","width":3},"mode":"lines","name":"Calcarine sulcus anterior - Lingual gyrus (0.00)","x":[-12.32832434894803,19.530965926045596],"y":[-73.99620824948485,-68.49313859945124],"z":[7.341546442399604,-9.619777515737866],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet": ...
